# %% [markdown]
# # Matplotlib Exercise AI 240 - 10459
#
# # Instructor - Dr. Uma Gajendragadkar

# %% [markdown]
# ## Use slides from the class and do below exercises
# Use cars dataset if you want for below charts otherwise use data given in slides and draw all below charts in Matplotlib.
#
# Exercise 1 -  Install Matplotlib Library using instruction
#
# !pip install matplotlib

# %% [markdown]
# ## Exercise 1 - Install Matplotlib Library using instruction

# %%
# !pip install matplotlib

# %% [markdown]
# ## Exercise 2 - Import Matplotlib using
#
# import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 3 - Draw Barchart

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([5, 7, 3, 11])

plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Exercise 4 -  Draw Histogram

# %%
# Generate random data
data = np.random.randn(1000)

# Create a histogram with density and custom color
plt.hist(data, bins=30, density=True, color='blue', edgecolor='black', alpha=0.7)

plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Customized Histogram with Density')

plt.show()

# %% [markdown]
# ## Exercise 5 -  Draw Piechart

# %%
y = np.array([35, 25, 25, 15])
plt.pie(y)
plt.show()

# %% [markdown]
# ## Other Exercises from Lecture

# %%
# Draw a Sine Wave
import numpy as np

x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots(figsize=(7, 4))

ax.set_title('Sin Wave')
ax.plot(x, y)
plt.show()

# %%
# Draw a Line - Draw a line in a diagram from position (0,0) to position (5,200):

xpoints = np.array([0, 5])
ypoints = np.array([0, 200])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# Add labels to x and y

x = np.array([1989, 1992, 1990, 1995, 2000, 2025, 2022, 2018, 2019, 2023])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Year")
plt.ylabel("Price")
           
plt.show()

# %%
# Add Grid Lines to plots

x = np.array([90, 75, 80, 55, 104, 103, 99, 88, 78, 94])
y = np.array([140, 550, 450, 880, 480, 270, 490,300, 430, 360])

plt.title("Sports Data")

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnt")

plt.plot(x, y)
plt.grid()

plt.show()

# %%
# Scatterplot

x = np.array([15,17,8,7,2,7,12,19,4,10,14,8,5])
y = np.array([111,86,103,87,99,86,87,88,94,78,77,85,86])

plt.scatter(x, y)

plt.show()

# %% [markdown]
# (Bar chart, Histogram, Piechart above)

# %%
# 3D plot

from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Generating 3D data
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

# Creating a basic 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c='blue', marker='o', label='Data Points')

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')
ax.set_title('Basic 3D Scatter Plot')
# Out:
# Text(0.5, 0.92, 'Basic 3D Scatter Plot')

# %%
# 3D bar plot

from mpl_toolkits.mplot3d import Axes3D
vehicle_type = ['Car']
sales_region = ['North', 'South']
sales_volume = [[150, 120]]

# Creating a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
                     
# Plotting 3D bars
for i in range(len(vehicle_type)):
    for j in range(len(sales_region)):
        ax.bar3d(i, j, 0, 0.8, 0.8, sales_volume[i][j])

ax.set_xlabel('Vehicle Type')
ax.set_ylabel('Sales Region')
ax.set_zlabel('Sales Volume')
ax.set_title('Basic 3D Bar Graph')

# Displaying the plot
plt.show()

# %%
# Seaborn Displot

import seaborn as sns
sns.displot([0, 1, 2, 3, 4, 5])
plt.show()
